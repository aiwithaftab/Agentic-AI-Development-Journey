# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
llm.invoke("My name is Aftab").content
# Out:
# 'Hello Aftab! Nice to meet you.'

# %%
messages = ["what is my name?"]

# %%
output = llm.invoke(messages).content
output
# Out:
# "I don't have a way of knowing your name. As an AI, I don't have access to personal data about users. I don't store information from our conversations or know who you are.\n\nYou can tell me if you'd like, or we can just continue our conversation!"

# %%
messages.append(output)
messages
