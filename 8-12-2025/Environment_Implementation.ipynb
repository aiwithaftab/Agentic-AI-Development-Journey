# %%
class Environment:
  def execute_action(self, arg: dict, action:Action) -> dict:
    try:
      result = result.execute(**args)
      return self.format_result(result)
    except exception as e:
      return {
          "tool_executed": False,
          "error": str{e},
          "traceback": traceback.format_exc()
      }

  def format_result(self, result: dict) -> dict:
    return {
        "tool_executed": True,
        "result": result
    }
